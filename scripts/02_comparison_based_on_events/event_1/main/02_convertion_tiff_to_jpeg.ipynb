# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

for root, dirs, files in os.walk("/content/drive"):
    for d in dirs:
        if "Hasdeo" in d:
            print(os.path.join(root,d))

# %%
import os

matches = []

for root, dirs, files in os.walk("/content/drive"):
    for d in dirs:
        if d == "Hasdeo_Training_Dataset":
            matches.append(os.path.join(root,d))

matches
# Out:
# []

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.24.2)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2026.1.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
import gdown

gdown.download_folder(
    "https://drive.google.com/drive/folders/14tQ7B7Y_LpPTll5CUU6w3mDwlhNREm1-?usp=share_link",
    output="data",
    quiet=False
)
# Out:
# Retrieving folder contents
# Processing file 1BIyJFZFQYHD_RWyQQUtjXzC4AjCpT2cF ANN_Hasdeo_Full_2016.tif
# Processing file 1ycjY5AS361Czw3j0h_arHCPl7f5W0LpT ANN_Hasdeo_Full_2017.tif
# Processing file 198SFCMoCIAY1mnibo7qQcZkBn7N2hoFg ANN_Hasdeo_Full_2018.tif
# Processing file 1XkObl0ASYHq0AM3aWuiZ-aRWxgi0fBNK ANN_Hasdeo_Full_2019.tif
# Processing file 1Wv6WCn5v8ngowD0YlLn_OzoyPUMpx93T ANN_Hasdeo_Full_2020.tif
# Processing file 1gT-YXnu984F8e8J1uqa14YTRjvTrJRrR ANN_Hasdeo_Full_2021.tif
# Processing file 10jCbPbvtfGy_Oplj-J2GYdZMdBllf-_2 ANN_Hasdeo_Full_2022.tif
# Processing file 10_frXzy0KkKv285F6JWMC1G6Hykixvzk ANN_Hasdeo_Full_2023.tif
# Processing file 1j-IE9r1g8xDbHlLOQwQEhqAxwz-Ztsfg ANN_Hasdeo_Full_2024.tif
# Processing file 1hAqma9UCp4AdllqPZlj9rCvQxwVDQJiN ANN_Hasdeo_Full_2025.tif
# Processing file 197gzqNzlEmrCQKgmNvmwfIzLxGyIUNgX ANN_Kente_Extension_2016.tif
# Processing file 1HWjagTJ0dIZAJVx-ej8f6erE3aeC_pkr ANN_Kente_Extension_2018.tif
# Processing file 1Vy3gbJrev5ZnLnSLYZZtb_gDelOXOCFr ANN_Kente_Extension_2019.tif
# Processing file 1FJ71dMHhxz5_wQj35UB5js5ND7IIoxZP ANN_Kente_Extension_2020.tif
# Processing file 1gPc-4o0pzUVm9OQz9DJ0Sr36xf4ZeFT_ ANN_PEKB_Core_2016.tif
# Processing file 12O1TBtN0xBqAt7X_JkYCQmKKEbjAH3nH ANN_PEKB_Core_2017.tif
# Processing file 1C3h7AqJj9xkPlrVUAexodXnmlTC6t5GG ANN_PEKB_Core_2018.tif
# Processing file 1B42oDAG5gW_wLe_4idWz8n9wgtXZjzT4 ANN_PEKB_Core_2019.tif
# Processing file 1a6qcfBVGsUZ2lh3Th9mqj4m1naEmYSDp ANN_PEKB_Core_2020.tif
# Processing file 1R3GwpyGZGd64NOXpSAJvxKXhqtUBrusu ANN_PEKB_Core_2021.tif
# Processing file 1vYoY-CE4DIRlENYr_PZk-YhCak_kCw6i ANN_PEKB_Core_2022.tif
# Processing file 1HCTcCzvi0JnoGgM2w99ZKhpNtC09JGNO ANN_PEKB_Core_2023.tif
# Processing file 1im_yNKaypsbBOUR9ZLo6BZh8Xgla8S1e ANN_PEKB_Core_2024.tif
# Processing file 1rAsphh6SUejhZdE9LkmyzP3N_cNqiVtB MON_Control_Forest_2020_02_slowdown.tif
# Processing file 1WQibRhGARnt-rktMvPNB0--U04Hf7V2- MON_Control_Forest_2020_03_slowdown.tif
# ---------------------------------------------------------------------------
# FolderContentsMaximumLimitError           Traceback (most recent call last)
# /tmp/ipython-input-1476399244.py in <cell line: 0>()
#       1 import gdown
#       2
# ----> 3 gdown.download_folder(
#       4     "https://drive.google.com/drive/folders/14tQ7B7Y_LpPTll5CUU6w3mDwlhNREm1-?usp=share_link",
#       5     output="data",
#
# /usr/local/lib/python3.12/dist-packages/gdown/download_folder.py in download_folder(url, id, output, quiet, proxy, speed, use_cookies, remaining_ok, verify, user_agent, skip_download, resume)
#     273     if not quiet:
#     274         print("Retrieving folder contents", file=sys.stderr)
# --> 275     is_success, gdrive_file = _download_and_parse_google_drive_link(
#     276         sess,
#     277         url,
#
# /usr/local/lib/python3.12/dist-packages/gdown/download_folder.py in _download_and_parse_google_drive_link(sess, url, quiet, remaining_ok, verify)
#     174             ]
#     175         )
# --> 176         raise FolderContentsMaximumLimitError(message)
#     177     return return_code, gdrive_file
#     178
#
# FolderContentsMaximumLimitError: The gdrive folder with url: https://drive.google.com/drive/folders/14tQ7B7Y_LpPTll5CUU6w3mDwlhNREm1-?usp=share_link&hl=en has more than 50 files, gdrive can't download more than this limit.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

for root, dirs, files in os.walk("/content/drive"):
    for d in dirs:
        if "Hasdeo_Training_Dataset" in d:
            print(os.path.join(root,d))
# Out:
# /content/drive/.shortcut-targets-by-id/14tQ7B7Y_LpPTll5CUU6w3mDwlhNREm1-/Hasdeo_Training_Dataset
# /content/drive/MyDrive/Hasdeo_Training_Dataset

# %%
input_folder = "/content/drive/MyDrive/Hasdeo_Training_Dataset"

# %%
import os
os.listdir(input_folder)[:5]
# Out:
# ['MON_Kente_Extension_2020_04_slowdown.tif',
#  'MON_Kente_Extension_2020_05_slowdown.tif',
#  'MON_Kente_Extension_2020_09_slowdown.tif',
#  'MON_Kente_Extension_2020_06_slowdown.tif',
#  'MON_Kente_Extension_2021_01_slowdown.tif']

# %%
import rasterio
import numpy as np
from PIL import Image
import os

output_folder = "/content/jpg_output"
os.makedirs(output_folder, exist_ok=True)

def stretch(x):
    x = np.nan_to_num(x)
    x_valid = x[x>0]
    if len(x_valid)==0:
        return np.zeros_like(x)

    p2,p98 = np.percentile(x_valid,(2,98))
    if p98-p2 == 0:
        return np.zeros_like(x)

    return np.clip((x-p2)/(p98-p2),0,1)

files = sorted([f for f in os.listdir(input_folder) if f.endswith(".tif")])[:10]

for file in files:

    path = os.path.join(input_folder,file)

    with rasterio.open(path) as src:
        r = src.read(3).astype(float)
        g = src.read(2).astype(float)
        b = src.read(1).astype(float)

    r,g,b = stretch(r), stretch(g), stretch(b)

    rgb = np.dstack((r,g,b))
    rgb = (rgb*255).astype(np.uint8)

    Image.fromarray(rgb).save(f"{output_folder}/{file}.jpg")

    print("Converted:", file)
# Out:
# Converted: ANN_Control_Forest_2016.tif
# Converted: ANN_Control_Forest_2018.tif
# Converted: ANN_Hasdeo_Full_2016.tif
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# CPLE_AppDefinedError: TIFFFillTile:Read error at row 4294967295, col 4294967295, tile 0; got 262972 bytes, expected 2087767
#
# The above exception was the direct cause of the following exception:
#
# CPLE_AppDefinedError                      Traceback (most recent call last)
# CPLE_AppDefinedError: TIFFReadEncodedTile() failed.
#
# The above exception was the direct cause of the following exception:
#
# CPLE_AppDefinedError                      Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/rasterio/_io.pyx in rasterio._io.DatasetReaderBase._read()
#
# /usr/local/lib/python3.12/dist-packages/rasterio/_io.pyx in rasterio._io.io_multi_band()
#
# /usr/local/lib/python3.12/dist-packages/rasterio/_io.pyx in rasterio._io.io_multi_band()
#
# /usr/local/lib/python3.12/dist-packages/rasterio/_err.pyx in rasterio._err.StackChecker.exc_wrap_int()
#
# CPLE_AppDefinedError: ANN_Hasdeo_Full_2017.tif, band 3: IReadBlock failed at X offset 0, Y offset 0: TIFFReadEncodedTile() failed.
#
# The above exception was the direct cause of the following exception:
#
# RasterioIOError                           Traceback (most recent call last)
# /tmp/ipython-input-65825320.py in <cell line: 0>()
#      26
#      27     with rasterio.open(path) as src:
# ---> 28         r = src.read(3).astype(float)
#      29         g = src.read(2).astype(float)
#      30         b = src.read(1).astype(float)
#
# /usr/local/lib/python3.12/dist-packages/rasterio/_io.pyx in rasterio._io.DatasetReaderBase.read()
#
# /usr/local/lib/python3.12/dist-packages/rasterio/_io.pyx in rasterio._io.DatasetReaderBase._read()
#
# RasterioIOError: Read failed. See previous exception for details.

# %%
import os
import rasterio
import numpy as np
from PIL import Image

# ==============================
# SETTINGS
# ==============================

input_folder = "/content/drive/MyDrive/Hasdeo_Training_Dataset"  # change if needed
output_folder = "/content/jpg_output"
max_images = 10
scale = 4   # 2=high quality, 4=balanced, 8=fastest

os.makedirs(output_folder, exist_ok=True)

# ==============================
# SAFE STRETCH FUNCTION
# ==============================

def stretch(x):
    x = np.nan_to_num(x, nan=0.0, posinf=0.0, neginf=0.0)

    valid = x[x > 0]
    if len(valid) == 0:
        return np.zeros_like(x)

    p2, p98 = np.percentile(valid, (2, 98))

    if p98 - p2 == 0:
        return np.zeros_like(x)

    return np.clip((x - p2) / (p98 - p2), 0, 1)

# ==============================
# FILE LIST
# ==============================

files = sorted([f for f in os.listdir(input_folder) if f.endswith(".tif")])[:max_images]

print("Processing", len(files), "files\n")

# ==============================
# PROCESS LOOP
# ==============================

failed = []

for file in files:

    path = os.path.join(input_folder, file)

    try:
        with rasterio.open(path) as src:

            r = src.read(3, out_shape=(src.height//scale, src.width//scale))
            g = src.read(2, out_shape=(src.height//scale, src.width//scale))
            b = src.read(1, out_shape=(src.height//scale, src.width//scale))

        r = stretch(r)
        g = stretch(g)
        b = stretch(b)

        rgb = np.dstack((r, g, b))
        rgb = (rgb * 255).astype(np.uint8)

        save_path = os.path.join(output_folder, file.replace(".tif",".jpg"))
        Image.fromarray(rgb).save(save_path)

        print("✔ Converted:", file)

    except Exception as e:
        print("✖ Skipped:", file)
        failed.append((file,str(e)))

# ==============================
# REPORT
# ==============================

print("\nDone\n")

if failed:
    print("Failed Files:")
    for f,e in failed:
        print("-",f)
else:
    print("No failures")

# ==============================
# ZIP OUTPUT
# ==============================

import shutil
shutil.make_archive("converted_images","zip",output_folder)

print("\nZIP ready: converted_images.zip")
# Out:
# Processing 10 files
#
# ✔ Converted: ANN_Control_Forest_2016.tif
# ✔ Converted: ANN_Control_Forest_2018.tif
# ✔ Converted: ANN_Hasdeo_Full_2016.tif
# ✔ Converted: ANN_Hasdeo_Full_2017.tif
# ✔ Converted: ANN_Hasdeo_Full_2018.tif
# ✔ Converted: ANN_Hasdeo_Full_2019.tif
# ✔ Converted: ANN_Hasdeo_Full_2020.tif
# ✔ Converted: ANN_Hasdeo_Full_2021.tif
# ✔ Converted: ANN_Hasdeo_Full_2022.tif
# ✔ Converted: ANN_Hasdeo_Full_2023.tif
#
# Done
#
# No failures
#
# ZIP ready: converted_images.zip

# %%
import os
import rasterio
import numpy as np
from PIL import Image
import shutil

# ==============================
# SETTINGS
# ==============================

input_folder = "/content/drive/MyDrive/Hasdeo_Training_Dataset"
output_folder = "/content/jpg_output"
scale = 4   # 2=high quality | 4=balanced | 8=fastest

os.makedirs(output_folder, exist_ok=True)

# ==============================
# STRETCH FUNCTION
# ==============================

def stretch(x):
    x = np.nan_to_num(x, nan=0.0, posinf=0.0, neginf=0.0)
    valid = x[x > 0]
    if len(valid) == 0:
        return np.zeros_like(x)

    p2, p98 = np.percentile(valid, (2, 98))
    if p98 - p2 == 0:
        return np.zeros_like(x)

    return np.clip((x - p2) / (p98 - p2), 0, 1)

# ==============================
# GET ALL TIFF FILES
# ==============================

files = sorted([f for f in os.listdir(input_folder) if f.endswith(".tif")])

print("Total TIFF files:", len(files), "\n")

# ==============================
# PROCESS LOOP
# ==============================

failed = []

for i, file in enumerate(files, 1):

    path = os.path.join(input_folder, file)

    try:
        with rasterio.open(path) as src:

            r = src.read(3, out_shape=(src.height//scale, src.width//scale))
            g = src.read(2, out_shape=(src.height//scale, src.width//scale))
            b = src.read(1, out_shape=(src.height//scale, src.width//scale))

        r,g,b = stretch(r), stretch(g), stretch(b)

        rgb = np.dstack((r,g,b))
        rgb = (rgb*255).astype(np.uint8)

        save_path = os.path.join(output_folder, file.replace(".tif",".jpg"))
        Image.fromarray(rgb).save(save_path)

        print(f"[{i}/{len(files)}] ✔ {file}")

    except Exception as e:
        print(f"[{i}/{len(files)}] ✖ Skipped:", file)
        failed.append(file)

# ==============================
# ZIP OUTPUT
# ==============================

zip_path = "converted_images"
shutil.make_archive(zip_path, 'zip', output_folder)

print("\nZIP READY → converted_images.zip")

# ==============================
# FAILURE REPORT
# ==============================

if failed:
    print("\nFailed files:")
    for f in failed:
        print("-",f)
else:
    print("\nAll files processed successfully")
# Out:
# Total TIFF files: 374
#
# [1/374] ✔ ANN_Control_Forest_2016.tif
# [2/374] ✔ ANN_Control_Forest_2018.tif
# [3/374] ✔ ANN_Hasdeo_Full_2016.tif
# [4/374] ✔ ANN_Hasdeo_Full_2017.tif
# [5/374] ✔ ANN_Hasdeo_Full_2018.tif
# [6/374] ✔ ANN_Hasdeo_Full_2019.tif
# [7/374] ✔ ANN_Hasdeo_Full_2020.tif
# [8/374] ✔ ANN_Hasdeo_Full_2021.tif
# [9/374] ✔ ANN_Hasdeo_Full_2022.tif
# [10/374] ✔ ANN_Hasdeo_Full_2023.tif
# [287/374] ✔ MON_Kente_Extension_2024_02_renewed.tif
# [288/374] ✔ MON_Kente_Extension_2024_03_renewed.tif
# [289/374] ✔ MON_Kente_Extension_2024_04_renewed.tif
# [290/374] ✔ MON_Kente_Extension_2024_05_renewed.tif
# [291/374] ✔ MON_Kente_Extension_2024_06_renewed.tif
# [292/374] ✔ MON_Kente_Extension_2024_10_renewed.tif
# [293/374] ✔ MON_Kente_Extension_2024_11_renewed.tif
# [294/374] ✔ MON_Kente_Extension_2024_12_renewed.tif
# [295/374] ✔ MON_Kente_Extension_2025_01_renewed.tif
# [296/374] ✔ MON_Kente_Extension_2025_02_renewed.tif
# [297/374] ✔ MON_Kente_Extension_2025_03_renewed.tif
# [298/374] ✔ MON_Kente_Extension_2025_04_renewed.tif
# [299/374] ✔ MON_Kente_Extension_2025_05_renewed.tif
# [300/374] ✔ MON_Kente_Extension_2025_06_renewed.tif
# [301/374] ✔ MON_Mining_Buffer_2016_10_rapid_exp.tif
# [302/374] ✔ MON_Mining_Buffer_2016_11_rapid_exp.tif
# [303/374] ✔ MON_Mining_Buffer_2017_01_rapid_exp.tif
# [304/374] ✔ MON_Mining_Buffer_2017_02_rapid_exp.tif
# [305/374] ✔ MON_Mining_Buffer_2017_03_rapid_exp.tif
# [306/374] ✔ MON_Mining_Buffer_2017_11_rapid_exp.tif
# [307/374] ✔ MON_Mining_Buffer_2017_12_rapid_exp.tif
# [308/374] ✔ MON_Mining_Buffer_2018_01_rapid_exp.tif
# [309/374] ✔ MON_Mining_Buffer_2018_02_rapid_exp.tif
# [310/374] ✔ MON_Mining_Buffer_2018_03_rapid_exp.tif
# [311/374] ✔ MON_Mining_Buffer_2018_04_rapid_exp.tif
# [312/374] ✔ MON_Mining_Buffer_2018_10_rapid_exp.tif
# [313/374] ✔ MON_Mining_Buffer_2018_11_rapid_exp.tif
# [314/374] ✔ MON_Mining_Buffer_2018_12_rapid_exp.tif
# [315/374] ✔ MON_Mining_Buffer_2019_01_rapid_exp.tif
# [316/374] ✔ MON_Mining_Buffer_2019_02_rapid_exp.tif
# [317/374] ✔ MON_Mining_Buffer_2019_03_rapid_exp.tif
# [318/374] ✔ MON_Mining_Buffer_2019_04_rapid_exp.tif
# [319/374] ✔ MON_Mining_Buffer_2019_05_rapid_exp.tif
# [320/374] ✔ MON_Mining_Buffer_2019_06_rapid_exp.tif
# [321/374] ✔ MON_Mining_Buffer_2019_10_rapid_exp.tif
# [322/374] ✔ MON_Mining_Buffer_2019_11_rapid_exp.tif
# [323/374] ✔ MON_Mining_Buffer_2019_12_rapid_exp.tif
# [324/374] ✔ MON_Mining_Buffer_2020_01_slowdown.tif
# [325/374] ✔ MON_Mining_Buffer_2020_02_slowdown.tif
# [326/374] ✔ MON_Mining_Buffer_2020_03_slowdown.tif
# [327/374] ✔ MON_Mining_Buffer_2020_04_slowdown.tif
# [328/374] ✔ MON_Mining_Buffer_2020_05_slowdown.tif
# [329/374] ✔ MON_Mining_Buffer_2020_06_slowdown.tif
# [330/374] ✔ MON_Mining_Buffer_2020_09_slowdown.tif
# [331/374] ✔ MON_Mining_Buffer_2020_10_slowdown.tif
# [332/374] ✔ MON_Mining_Buffer_2020_11_slowdown.tif
# [333/374] ✔ MON_Mining_Buffer_2020_12_slowdown.tif
# [334/374] ✔ MON_Mining_Buffer_2021_01_slowdown.tif
# [335/374] ✔ MON_Mining_Buffer_2021_02_slowdown.tif
# [336/374] ✔ MON_Mining_Buffer_2021_03_slowdown.tif
# [337/374] ✔ MON_Mining_Buffer_2021_04_slowdown.tif
# [338/374] ✔ MON_Mining_Buffer_2021_05_slowdown.tif
# [339/374] ✔ MON_Mining_Buffer_2021_07_slowdown.tif
# [340/374] ✔ MON_Mining_Buffer_2021_10_slowdown.tif
# [341/374] ✔ MON_Mining_Buffer_2021_11_slowdown.tif
# [342/374] ✔ MON_Mining_Buffer_2021_12_slowdown.tif
# [343/374] ✔ MON_Mining_Buffer_2022_01_slowdown.tif
# [344/374] ✔ MON_Mining_Buffer_2022_02_slowdown.tif
# [345/374] ✔ MON_Mining_Buffer_2022_03_slowdown.tif
# [346/374] ✔ MON_Mining_Buffer_2022_04_slowdown.tif
# [347/374] ✔ MON_Mining_Buffer_2022_05_slowdown.tif
# [348/374] ✔ MON_Mining_Buffer_2022_10_slowdown.tif
# [349/374] ✔ MON_Mining_Buffer_2022_11_slowdown.tif
# [350/374] ✔ MON_Mining_Buffer_2022_12_slowdown.tif
# [351/374] ✔ MON_Mining_Buffer_2023_01_renewed.tif
# [352/374] ✔ MON_Mining_Buffer_2023_02_renewed.tif
# [353/374] ✔ MON_Mining_Buffer_2023_03_renewed.tif
# [354/374] ✔ MON_Mining_Buffer_2023_04_renewed.tif
# [355/374] ✔ MON_Mining_Buffer_2023_05_renewed.tif
# [356/374] ✔ MON_Mining_Buffer_2023_06_renewed.tif
# [357/374] ✔ MON_Mining_Buffer_2023_10_renewed.tif
# [358/374] ✔ MON_Mining_Buffer_2023_11_renewed.tif
# [359/374] ✔ MON_Mining_Buffer_2023_12_renewed.tif
# [360/374] ✔ MON_Mining_Buffer_2024_01_renewed.tif
# [361/374] ✔ MON_Mining_Buffer_2024_02_renewed.tif
# [362/374] ✔ MON_Mining_Buffer_2024_03_renewed.tif
# [363/374] ✔ MON_Mining_Buffer_2024_04_renewed.tif
# [364/374] ✔ MON_Mining_Buffer_2024_05_renewed.tif
# [365/374] ✔ MON_Mining_Buffer_2024_06_renewed.tif
# [366/374] ✔ MON_Mining_Buffer_2024_10_renewed.tif
# [367/374] ✔ MON_Mining_Buffer_2024_11_renewed.tif
# [368/374] ✔ MON_Mining_Buffer_2024_12_renewed.tif
# [369/374] ✔ MON_Mining_Buffer_2025_01_renewed.tif
# [370/374] ✔ MON_Mining_Buffer_2025_02_renewed.tif
# [371/374] ✔ MON_Mining_Buffer_2025_03_renewed.tif
# [372/374] ✔ MON_Mining_Buffer_2025_04_renewed.tif
# [373/374] ✔ MON_Mining_Buffer_2025_05_renewed.tif
# [374/374] ✔ MON_Mining_Buffer_2025_06_renewed.tif
#
# ZIP READY → converted_images.zip
#
# All files processed successfully

# %%
from google.colab import files
files.download("converted_images.zip")
